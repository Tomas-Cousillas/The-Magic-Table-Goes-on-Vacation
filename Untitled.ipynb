# %%
import app
# Out:
# ['AB_NYC_2019']
# C:\Users\Shaena\Anaconda3\lib\site-packages\flask_sqlalchemy\__init__.py:835: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
app.Select_B(['Brooklyn'])
# Out:
# [{'id': 2539,
#   'name': 'Clean & quiet apt home by the park',
#   'neighbourhood_group': 'Brooklyn',
#   'latitude': 40.64749,
#   'longitude': -73.97237,
#   'room_type': 'Private room',
#   'price': 149,
#   'minimum_nights': 1},
#  {'id': 3831,
#   'name': 'Cozy Entire Floor of Brownstone',
#   'neighbourhood_group': 'Brooklyn',
#   'latitude': 40.68514,
#   'longitude': -73.95976,
#   'room_type': 'Entire home/apt',
#   'price': 89,
#   'minimum_nights': 1},
#  {'id': 5121,
#   'name': 'BlissArtsSpace!',
#   'neighbourhood_group': 'Brooklyn',
#   'latitude': 40.68688,
#   'longitude': -73.95596,
#   'room_type': 'Private room',
#   'price': 60,
#   'minimum_nights': 45},
#  {'id': 5803,
#   'name': 'Lovely Room 1, Garden, Best Area, Legal rental',
#   'neighbourhood_group': 'Brooklyn',
#   'latitude': 40.66829,
#   'longitude': -73.98779,
#   'room_type': 'Private room',
#   'price': 89,
#   'minimum_nights': 4},
#  {'id': 6848,
#   'name': 'Only 2 stops to Manhattan studio',
# ...

# %%
app.Cheapest(["Brooklyn"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-76f26d7c735d> in <module>
# ----> 1 app.Cheapest(["Brooklyn"])
#
# ~\Desktop\HOMEWORK\New folder\The-Magic-Table-Goes-on-Vacation\app.py in Cheapest(neighbourhood_group)
#      79     for result in price_results:
#      80         cheap_dict = {}
# ---> 81         price_results["latitude"] = result[0]
#      82         price_results["longitude"] = result[1]
#      83         price_results["price"] = result[2]
#
# TypeError: list indices must be integers or slices, not str

# %%
]
# Out:
#   File "<ipython-input-19-de603c91038f>", line 1
#     ]
#     ^
# SyntaxError: invalid syntax
