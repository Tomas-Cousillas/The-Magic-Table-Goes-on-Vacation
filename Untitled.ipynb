# %%
import app
# Out:
# ['AB_NYC_2019']
# C:\Users\Shaena\Anaconda3\lib\site-packages\flask_sqlalchemy\__init__.py:835: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
app.Select_B("Queens")
# Out:
# [{'id': 12937,
#   'name': '1 Stop fr. Manhattan! Private Suite,Landmark Block',
#   'neighbourhood_group': 'Queens',
#   'latitude': 40.74771,
#   'longitude': -73.9474,
#   'room_type': 'Private room',
#   'price': 130,
#   'minimum_nights': 3},
#  {'id': 18198,
#   'name': 'Little King of Queens',
#   'neighbourhood_group': 'Queens',
#   'latitude': 40.75038,
#   'longitude': -73.90334,
#   'room_type': 'Private room',
#   'price': 70,
#   'minimum_nights': 30},
#  {'id': 32363,
#   'name': 'Fully Furnished Basement Apartment',
#   'neighbourhood_group': 'Queens',
#   'latitude': 40.74028,
#   'longitude': -73.83168,
#   'room_type': 'Private room',
#   'price': 140,
#   'minimum_nights': 2},
#  {'id': 39593,
#   'name': 'A room w/ a Manhattan view, longer stay',
#   'neighbourhood_group': 'Queens',
#   'latitude': 40.74559,
#   'longitude': -73.92313,
#   'room_type': 'Private room',
#   'price': 79,
#   'minimum_nights': 30},
#  {'id': 45910,
# ...
