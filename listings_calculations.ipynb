# %%
import pandas as pd

# %%
listings_df = pd.read_csv("AB_NYC_2019.csv")

# %%
listings_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
listings_df.describe().round(2)
# Out:
#                 id       host_id  latitude  longitude     price  \
# count     48895.00  4.889500e+04  48895.00   48895.00  48895.00
# mean   19017143.24  6.762001e+07     40.73     -73.95    152.72
# std    10983108.39  7.861097e+07      0.05       0.05    240.15
# min        2539.00  2.438000e+03     40.50     -74.24      0.00
# 25%     9471945.00  7.822033e+06     40.69     -73.98     69.00
# 50%    19677284.00  3.079382e+07     40.72     -73.96    106.00
# 75%    29152178.50  1.074344e+08     40.76     -73.94    175.00
# max    36487245.00  2.743213e+08     40.91     -73.71  10000.00
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count        48895.00           48895.00           38843.00
# mean             7.03              23.27               1.37
# std             20.51              44.55               1.68
# min              1.00               0.00               0.01
# 25%              1.00               1.00               0.19
# ...

# %%
listings_df.groupby(["neighbourhood"]).count().sort_values(by=["id"], ascending = False).head()
# Out:
#                       id  name  host_id  host_name  neighbourhood_group  \
# neighbourhood
# Williamsburg        3920  3918     3920       3919                 3920
# Bedford-Stuyvesant  3714  3713     3714       3714                 3714
# Harlem              2658  2657     2658       2656                 2658
# Bushwick            2465  2463     2465       2464                 2465
# Upper West Side     1971  1970     1971       1970                 1971
#
#                     latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood
# Williamsburg            3920       3920       3920   3920            3920
# Bedford-Stuyvesant      3714       3714       3714   3714            3714
# Harlem                  2658       2658       2658   2658            2658
# Bushwick                2465       2465       2465   2465            2465
# Upper West Side         1971       1971       1971   1971            1971
#
# ...

# %%
# get averages per neighborhood
listings_df.groupby(["neighbourhood_group"]).max().round(2)
# Out:
#                            id    host_id    neighbourhood  latitude  \
# neighbourhood_group
# Bronx                36442252  273877318         Woodlawn     40.91
# Brooklyn             36485057  274307600  Windsor Terrace     40.74
# Manhattan            36487245  274321313     West Village     40.88
# Queens               36484363  274225617         Woodside     40.80
# Staten Island        36438336  272557707          Woodrow     40.65
#
#                      longitude    room_type  price  minimum_nights  \
# neighbourhood_group
# Bronx                   -73.78  Shared room   2500             365
# Brooklyn                -73.86  Shared room  10000             999
# Manhattan               -73.91  Shared room  10000            1250
# Queens                  -73.71  Shared room  10000             500
# Staten Island           -74.06  Shared room   5000             365
#
#                      number_of_reviews  reviews_per_month  \
# neighbourhood_group
# ...

# %%
# get averages per neighborhood
listings_df.groupby(["neighbourhood_group"]).count().round(2)
# Out:
#                         id   name  host_id  host_name  neighbourhood  \
# neighbourhood_group
# Bronx                 1091   1090     1091       1090           1091
# Brooklyn             20104  20098    20104      20095          20104
# Manhattan            21661  21652    21661      21652          21661
# Queens                5666   5666     5666       5664           5666
# Staten Island          373    373      373        373            373
#
#                      latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood_group
# Bronx                    1091       1091       1091   1091            1091
# Brooklyn                20104      20104      20104  20104           20104
# Manhattan               21661      21661      21661  21661           21661
# Queens                   5666       5666       5666   5666            5666
# Staten Island             373        373        373    373             373
#
# ...

# %%
#get room type availability by neighborhood
listings_df.groupby(["neighbourhood_group"])["room_type"].value_counts()
# Out:
# neighbourhood_group  room_type
# Bronx                Private room         652
#                      Entire home/apt      379
#                      Shared room           60
# Brooklyn             Private room       10132
#                      Entire home/apt     9559
#                      Shared room          413
# Manhattan            Entire home/apt    13199
#                      Private room        7982
#                      Shared room          480
# Queens               Private room        3372
#                      Entire home/apt     2096
#                      Shared room          198
# Staten Island        Private room         188
#                      Entire home/apt      176
#                      Shared room            9
# Name: room_type, dtype: int64

# %%
listings_df.groupby(["neighbourhood_group"])["price"].describe()
# Out:
#                        count        mean         std   min   25%    50%  \
# neighbourhood_group
# Bronx                 1091.0   87.496792  106.709349   0.0  45.0   65.0
# Brooklyn             20104.0  124.383207  186.873538   0.0  60.0   90.0
# Manhattan            21661.0  196.875814  291.383183   0.0  95.0  150.0
# Queens                5666.0   99.517649  167.102155  10.0  50.0   75.0
# Staten Island          373.0  114.812332  277.620403  13.0  50.0   75.0
#
#                        75%      max
# neighbourhood_group
# Bronx                 99.0   2500.0
# Brooklyn             150.0  10000.0
# Manhattan            220.0  10000.0
# Queens               110.0  10000.0
# Staten Island        110.0   5000.0

# %%
listings_df.groupby(["neighbourhood_group"])["number_of_reviews"].describe()
# Out:
#                        count       mean        std  min  25%   50%   75%  \
# neighbourhood_group
# Bronx                 1091.0  26.004583  42.214774  0.0  1.0   9.0  32.0
# Brooklyn             20104.0  24.202845  44.344868  0.0  1.0   6.0  25.0
# Manhattan            21661.0  20.985596  42.572277  0.0  1.0   4.0  19.0
# Queens                5666.0  27.700318  51.955853  0.0  1.0   7.0  32.0
# Staten Island          373.0  30.941019  44.830766  0.0  1.0  12.0  42.0
#
#                        max
# neighbourhood_group
# Bronx                321.0
# Brooklyn             488.0
# Manhattan            607.0
# Queens               629.0
# Staten Island        333.0

# %%
# Filter the data so that only listings in Manhattan are in a DataFrame
man_listings = listings_df.loc[listings_df["neighbourhood_group"] == "Manhattan", :]
# Filter the data so that only listings in Brooklyn are in a DataFrame
brooklyn_listings = listings_df.loc[listings_df["neighbourhood_group"] == "Brooklyn", :]
# Filter the data so that only listings in Bronx are in a DataFrame
bronx_listings = listings_df.loc[listings_df["neighbourhood_group"] == "Bronx", :]
# Filter the data so that only listings in Queens are in a DataFrame
queens_listings = listings_df.loc[listings_df["neighbourhood_group"] == "Queens", :]
# Filter the data so that only listings in Staten island are in a DataFrame
staten_listings = listings_df.loc[listings_df["neighbourhood_group"] == "Staten Island", :]

# %%
bronx_listings.groupby(["neighbourhood"]).count().sort_values(by=["id"], ascending = False).head()
# Out:
#                id  name  host_id  host_name  neighbourhood_group  latitude  \
# neighbourhood
# Kingsbridge    70    70       70         70                   70        70
# Fordham        63    62       63         63                   63        63
# Longwood       62    62       62         62                   62        62
# Mott Haven     60    60       60         60                   60        60
# Concourse      50    50       50         50                   50        50
#
#                longitude  room_type  price  minimum_nights  number_of_reviews  \
# neighbourhood
# Kingsbridge           70         70     70              70                 70
# Fordham               63         63     63              63                 63
# Longwood              62         62     62              62                 62
# Mott Haven            60         60     60              60                 60
# Concourse             50         50     50              50                 50
#
# ...

# %%
brooklyn_listings.groupby(["neighbourhood"]).count().sort_values(by=["id"], ascending = False).head()
# Out:
#                       id  name  host_id  host_name  neighbourhood_group  \
# neighbourhood
# Williamsburg        3920  3918     3920       3919                 3920
# Bedford-Stuyvesant  3714  3713     3714       3714                 3714
# Bushwick            2465  2463     2465       2464                 2465
# Crown Heights       1564  1564     1564       1563                 1564
# Greenpoint          1115  1115     1115       1113                 1115
#
#                     latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood
# Williamsburg            3920       3920       3920   3920            3920
# Bedford-Stuyvesant      3714       3714       3714   3714            3714
# Bushwick                2465       2465       2465   2465            2465
# Crown Heights           1564       1564       1564   1564            1564
# Greenpoint              1115       1115       1115   1115            1115
#
# ...

# %%
man_listings.groupby(["neighbourhood"]).count().sort_values(by=["id"], ascending = False).head()
# Out:
#                    id  name  host_id  host_name  neighbourhood_group  \
# neighbourhood
# Harlem           2658  2657     2658       2656                 2658
# Upper West Side  1971  1970     1971       1970                 1971
# Hell's Kitchen   1958  1957     1958       1955                 1958
# East Village     1853  1852     1853       1853                 1853
# Upper East Side  1798  1798     1798       1797                 1798
#
#                  latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood
# Harlem               2658       2658       2658   2658            2658
# Upper West Side      1971       1971       1971   1971            1971
# Hell's Kitchen       1958       1958       1958   1958            1958
# East Village         1853       1853       1853   1853            1853
# Upper East Side      1798       1798       1798   1798            1798
#
#                  number_of_reviews  last_review  reviews_per_month  \
# neighbourhood
# ...

# %%
queens_listings.groupby(["neighbourhood"]).count().sort_values(by=["id"], ascending = False).head()
# Out:
#                    id  name  host_id  host_name  neighbourhood_group  \
# neighbourhood
# Astoria           900   900      900        900                  900
# Long Island City  537   537      537        537                  537
# Flushing          426   426      426        426                  426
# Ridgewood         423   423      423        423                  423
# Sunnyside         363   363      363        363                  363
#
#                   latitude  longitude  room_type  price  minimum_nights  \
# neighbourhood
# Astoria                900        900        900    900             900
# Long Island City       537        537        537    537             537
# Flushing               426        426        426    426             426
# Ridgewood              423        423        423    423             423
# Sunnyside              363        363        363    363             363
#
#                   number_of_reviews  last_review  reviews_per_month  \
# ...

# %%
staten_listings.groupby(["neighbourhood"]).count().sort_values(by=["id"], ascending = False).head()
# Out:
#                id  name  host_id  host_name  neighbourhood_group  latitude  \
# neighbourhood
# St. George     48    48       48         48                   48        48
# Tompkinsville  42    42       42         42                   42        42
# Stapleton      27    27       27         27                   27        27
# Concord        26    26       26         26                   26        26
# Arrochar       21    21       21         21                   21        21
#
#                longitude  room_type  price  minimum_nights  number_of_reviews  \
# neighbourhood
# St. George            48         48     48              48                 48
# Tompkinsville         42         42     42              42                 42
# Stapleton             27         27     27              27                 27
# Concord               26         26     26              26                 26
# Arrochar              21         21     21              21                 21
#
# ...
